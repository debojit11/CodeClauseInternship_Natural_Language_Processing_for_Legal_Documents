# %%
from opennyai import Pipeline
from opennyai.utils import Data

# %%
text = '''Appeal No. 623 of 1975.
From the Judgment and Order dated 25 6 74 of the Karna taka 'High Court in Civil Revision No 1981/73.
S.S. JavaIi and B.P. Singh, for the Appellants.
S.V. Gupte and K.N. Bhatt, for the Respondent.
The Judgment of the Court was delivered by RAY, C.J.
This appeal by special leave is from the judgment .dated 25 June, 1974 of the Karnataka High Court.
The principal question in this appeal whether section 107 of the Karnataka Land Reforms Act, 1961 applies to the land in suit which was leased to the respondent.
A large plot of land comprising an area of about 20 acres popularly known as "The Chamaraja Sewage Farm" situate in the city of Bangalore belongs to the appellant Corpora tion.
The appellant :leased to the respondent by a regis tered lease dated 14 September, 270 1953 the aforementioned land for a period of 5 years on an annual rent of Rs. 13,555/ .
The respondent by notice was called upon to hand over possession of the land immediately after the expiry of the period of lease.
The respondent failed to deliver possession.
The reason why the appellant required that land is that the Corporation proposed a scheme for the development and construction of a new township on that area.
The respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession.
The Court upheld the contentions of the appellant that the lease had terminated by efflux of time.
The respondent 's 'suit was dismissed.
An appeal was pre ferred.
The appeal was dismissed on 21 August,.
The appellant then instituted the suit in appeal claim ing possession from the respondent.
The appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation.
The respondent contended that he was still a tenant.
The respondent claimed protection under the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 being Act No. 15 of 1961.
Section 3 of the Mysore Tenants (Temporary Protection from Evic .
tion) Act, 1961 provided for prohibition against eviction.
The appellant obtained a decree in the suit.
The decree directed the respondent to deliver possession.
The respond ent preferred an ' appeal.
The High Court remanded the matter to the trial Court for assessment of damages.
Upon remand the respondent applied for the amendment of the written statement.
The respondent claimed protection under the Karnataka Land Reforms Act, 1961.
It may be stated here that the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 ceased to be in force in March, 1966.
That is perhaps why the respondent made an applica tion for amendment of the written statement on 2 February 1973.
The respondent contended relying on section 133 of the Karnataka Land Reforms Act, 1961 that the.
suit should be stayed by the civil court and should be referred to the Tribunal for decision.
Section 112(B)(b) of the Karnataka Land Reforms Act, 1961 confers power on the Tribunal to decide inter alia whether a person is a tenant or not.
The respondent contended that he was a person who was deemed to be a tenant.
The appellant opposed the application for stay of the suit by the civil court and referring to the Tribunal for decision under the Karnataka Land Reforms Act, 1961.
The trial Court held that the land ' belonging to the appellant was exempted from the application of the provisions of the Land Reforms Act.
The trial Court dismissed the application of the respondent.
The respondent presented a revision petition t0 the High Court.
The High Court reversed the decision of the trial Court and directed the trial Court to refer such of the issues which are required to be.
decided by the Tribunal.
271 Counsel for the respondent contended that the respondent is a tenant within the meaning of the word "tenant" defined in section 2(34) of the Karnataka Land Reforms Act, 1961.
"Tenant" is defined to mean an agriculturist who cultivates personally the land he holds on lease from a landlord and includes (i) a person who is deemed to be a tenant under section 4 of the Karnataka Land Reforms Act, 1961, Section of the Karnataka Land Reforms Act, 1961 states that a person lawfully cultivating any land belonging to another person shall be deemed to be a tenant if such land is not cultivat ed personally by the owner and if such person is not (a) a member of the owner 's family, or (b) a servant or a hired labourer on wages, or (c) a mortgage in possession It was, therefore, said that the respondent could raise the con tention whether the respondent was a tenant or not.
It was next contended that section 8 of the Karnataka Land Reforms Act, 1961 speaks of rent and rent is referable to tenant and therefore a dispute as to tenancy would be within the ambit of the Karnataka Land Reforms Act, 1961.
Section 107 of the Karnataka Land Reforms Act, 1961 states that subject to the provisions of section 110 nothing in this Act, except section 8 shall apply to lands, inter alia (iii) belonging to or held on lease or from a local authority.
There is no dispute that the land was given on lease by the local authority.
There is also no 'dispute that the land belongs to the local authority.
There is also no dispute that the lease was detrmined by efflux of time.
The question whether the respondent is a tenant or deemed to be a tenant does not at all arise because the tenancy came to an end.
The 'respondent thereafter was a trespasser.
Section 107 of the Karnataka Land Reforms Act, 1961 makes it quite clear that the only provision which applies, inter alia, to lands belonging to or hold on lease or from a local authority is section 8.
No other section of the Land Reforms Act applies to these lands.
Section 8 of the Karna taka Land Reforms Act, 1961 deals with rent.
The suit in the present case was not for recovery of rent.
The suit is for recovery of possession and for damages, for unauthorised occupation of the respondent.
Section 2 of the Karnataka Land Reforms Act, 1961 is not applicable.
Therefore, no question can be referred for determination by the Tribunal under section 133.
The Mysore Tenants (Temporary Protection from Eviction) Act, 1961 came into effect on 13 December, 1961.
The Mysore Tenants (Temporary Protection from Eviction) Act, 1961 remained in force till the month of March, 1966.
The re spondent could not draw any support from that Act for pro tection against eviction.
The land in question was outside the applicability of the Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961.
Further the Act ceased to be in operation in 1966 and no question could be referred for determination as to whether the respondent was a tenant under the Mysore Tenants (Temporary Protection from Evic tion) Act, 1961 or not.
The trial Court in the present case rightly said that it could not be said that there was any dispute as to tenancy.
272 The respondent had filed a suit where he claimed to remain in possession.
The suit of the respondent was dismissed.
The appellant all along contended that the lease dated 14 September 1963 for a period of 5 years expired by efflux of time.
The appellant claimed possession on the ground Of unauthorised occupation and claimed damages against the respondent, who was a trespasser.
The High Court was clearly in error in referring to the Tribunal under the Karnataka Land Reforms Act 1961 determi nation of the plea taken by the respondent that he was pro tected by the Mysore Tenants (Temporary Protection from Eviction) Act 1961.
Counsel for the respondent did not support the judgment on that ground.
Counsel for the respondent contended that section 133 of the Karnataka Land Reforms Act 1961 excludes jurisdiction of Civil court in suits for possession where the defendant claims to be a tenant.
The plea of the respondent is utterly unsound.
Section 133 of the Karnataka Land Reforms Act 1961 cannot apply to lands which are held by a person on lease from the local authority or where the lease had ex pired and the local authority sues for possession on the ground that there is unauthorised occupation.
No provision of the Karnataka Land Reforms Act can be relied upon to contend that there should be protection against recovery of possession by the local authority.
For the foregoing reasons the judgment of the High Court is set aside.
In view of the fact that no costs were al lowed by the High Court, there will be no order as to costs.
M.R. Appeal allowed.'''

# %%
pipeline = Pipeline(components=['NER', 'Rhetorical_Role', 'Summarizer'], use_gpu=False, ner_do_sentence_level=True, ner_do_postprocess=True, ner_mini_batch_size=128, verbose=True)
# Out:
# ℹ Loading NER...
# ℹ NER will run on CPU!
# ℹ Loading Rhetorical Role...
# ℹ Rhetorical Roles will use CPU!
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ℹ Loading Extractive summarizer...
# ℹ Extractive Summarizer will use CPU!

# %%
data = Data(text)
# Out:
# ℹ Pre-processing will happen on CPU!

# %%
results = pipeline(data)
print(results)
# Out:
# ℹ Processing documents with Legal NER!!!
# 100%|██████████| 1/1 [00:15<00:00, 15.27s/it]
# ℹ Preprocessing rhetorical role model input!!!
# 100%|██████████| 1/1 [00:00<00:00, 119.56it/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ℹ Processing documents with rhetorical role model!!!
# 100%|██████████| 1/1 [00:15<00:00, 15.56s/it]
# ℹ Processing documents with extractive summarizer model!!!
# 100%|██████████| 1/1 [00:07<00:00,  7.26s/it]
# [{'id': '151d54820c2c627c8a676789fd9219bafdfeefbd4a9672c07ff368c2282fb358', 'data': {'text': 'Appeal No. 623 of 1975. \nFrom the Judgment and Order dated 25 6 74 of the Karna taka \'High Court in Civil Revision No 1981/73. \nS.S. JavaIi and B.P. Singh, for the Appellants. \nS.V. Gupte and K.N. Bhatt, for the Respondent. \nThe Judgment of the Court was delivered by RAY, C.J.\nThis appeal by special leave is from the judgment .dated 25 June, 1974 of the Karnataka High Court. \nThe principal question in this appeal whether section 107 of the Karnataka Land Reforms Act, 1961 applies to the land in suit which was leased to the respondent. \nA large plot of land comprising an area of about 20 acres popularly known as "The Chamaraja Sewage Farm" situate in the city of Bangalore belongs to the appellant Corpora tion. \nThe appellant :leased to the respondent by a regis tered lease dated 14 September, 270 1953 the aforementioned land for a period of 5 years on an annual rent of Rs. 13,555/ . \nThe respondent by notice was called upon to hand over possession of the land immediately after the expiry of the period of lease. \nThe respondent failed to deliver possession. \nThe reason why the appellant required that land is that the Corporation proposed a scheme for the development and construction of a new township on that area. \nThe respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession. \nThe Court upheld the contentions of the appellant that the lease had terminated by efflux of time. \nThe respondent \'s \'suit was dismissed. \nAn appeal was pre ferred. \nThe appeal was dismissed on 21 August,. \nThe appellant then instituted the suit in appeal claim ing possession from the respondent. \nThe appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation. \nThe respondent contended that he was still a tenant. \nThe respondent claimed protection under the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 being Act No. 15 of 1961. \nSection 3 of the Mysore Tenants (Temporary Protection from Evic .\ntion) Act, 1961 provided for prohibition against eviction. \nThe appellant obtained a decree in the suit. \nThe decree directed the respondent to deliver possession. \nThe respond ent preferred an \' appeal. \nThe High Court remanded the matter to the trial Court for assessment of damages. \nUpon remand the respondent applied for the amendment of the written statement. \nThe respondent claimed protection under the Karnataka Land Reforms Act, 1961. \nIt may be stated here that the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 ceased to be in force in March, 1966. \nThat is perhaps why the respondent made an applica tion for amendment of the written statement on 2 February 1973. \nThe respondent contended relying on section 133 of the Karnataka Land Reforms Act, 1961 that the.\nsuit should be stayed by the civil court and should be referred to the Tribunal for decision.\nSection 112(B)(b) of the Karnataka Land Reforms Act, 1961 confers power on the Tribunal to decide inter alia whether a person is a tenant or not.\nThe respondent contended that he was a person who was deemed to be a tenant.\nThe appellant opposed the application for stay of the suit by the civil court and referring to the Tribunal for decision under the Karnataka Land Reforms Act, 1961.\nThe trial Court held that the land \' belonging to the appellant was exempted from the application of the provisions of the Land Reforms Act.\nThe trial Court dismissed the application of the respondent.\nThe respondent presented a revision petition t0 the High Court. \nThe High Court reversed the decision of the trial Court and directed the trial Court to refer such of the issues which are required to be. \ndecided by the Tribunal. \n271 Counsel for the respondent contended that the respondent is a tenant within the meaning of the word "tenant" defined in ...

# %%
results[0]['annotations']
# Out:
# [{'start': 0,
#   'end': 23,
#   'text': 'Appeal No. 623 of 1975.',
#   'labels': ['PREAMBLE'],
#   'id': 'dbb13e31a79a45f1a531e2d70dd9fa7b_0',
#   'in_summary': True,
#   'summary_section': 'PREAMBLE',
#   'entities': [{'id': '76792e9f857c43f2ba8de38800cbe0f8',
#     'normalized_name': 'Appeal No. 623 of 1975',
#     'start': 0,
#     'end': 22,
#     'text': 'Appeal No. 623 of 1975',
#     'labels': ['CASE_NUMBER']}]},
#  {'start': 24,
#   'end': 126,
#   'text': "\nFrom the Judgment and Order dated 25 6 74 of the Karna taka 'High Court in Civil Revision No 1981/73.",
#   'labels': ['NONE'],
#   'id': '428d19804e9b43eaa561ee195390a753_1',
#   'in_summary': False,
#   'entities': [{'id': '7031e29ab88342c59a7533332fdaf709',
#     'normalized_name': '25 6 74',
#     'start': 59,
#     'end': 66,
#     'text': '25 6 74',
#     'labels': ['DATE']},
#    {'id': '8f29c039d2f44c00b307b36c9dbd1c0f',
#     'normalized_name': "Karna taka 'High Court",
#     'start': 74,
#     'end': 96,
#     'text': "Karna taka 'High Court",
#     'labels': ['COURT']},
#    {'id': '629bbc4f4105458e856b1d392a1c8513',
#     'normalized_name': 'Civil Revision No 1981/73',
#     'start': 100,
#     'end': 125,
#     'text': 'Civil Revision No 1981/73',
#     'labels': ['CASE_NUMBER']}]},
#  {'start': 127,
#   'end': 175,
#   'text': '\nS.S. JavaIi and B.P. Singh, for the Appellants.',
#   'labels': ['NONE'],
#   'id': 'c696e6fe7eb9415abf7b3d83a7c15639_2',
#   'in_summary': False,
#   'entities': [{'id': '11f2f9d6d7f1430bae78e016334c67c7',
#     'normalized_name': 'S.S. JavaIi',
#     'start': 128,
#     'end': 139,
#     'text': 'S.S. JavaIi',
#     'labels': ['OTHER_PERSON']},
#    {'id': 'cc487d9f171c4cc2b8f5a98e61747d78',
#     'normalized_name': 'B.P. Singh',
#     'start': 144,
#     'end': 154,
#     'text': 'B.P. Singh',
#     'labels': ['OTHER_PERSON']}]},
#  {'start': 176,
#   'end': 223,
#   'text': '\nS.V. Gupte and K.N. Bhatt, for the Respondent.',
#   'labels': ['NONE'],
#   'id': '6195efb921494955b1c7dfe0d0562788_3',
#   'in_summary': False,
#   'entities': [{'id': '57635ad33b5d4b108df8abad2bc54088',
#     'normalized_name': 'S.V. Gupte',
#     'start': 177,
#     'end': 187,
#     'text': 'S.V. Gupte',
#     'labels': ['OTHER_PERSON']},
#    {'id': '929f5c6aeb95426aa8d8daccb9e63f3e',
#     'normalized_name': 'K.N. Bhatt',
#     'start': 192,
#     'end': 202,
#     'text': 'K.N. Bhatt',
#     'labels': ['OTHER_PERSON']}]},
#  {'start': 224,
#   'end': 377,
#   'text': '\nThe Judgment of the Court was delivered by RAY, C.J.\nThis appeal by special leave is from the judgment .dated 25 June, 1974 of the Karnataka High Court.',
#   'labels': ['NONE'],
#   'id': 'fb0634768d864ac8b55f924dc52f5d96_4',
#   'in_summary': False,
#   'entities': [{'id': '6750362e9e2e4da4916d25e3674a6be0',
#     'normalized_name': 'RAY',
#     'start': 268,
#     'end': 271,
#     'text': 'RAY',
#     'labels': ['JUDGE']},
#    {'id': '037a4335fcf140b2ae15585d22b206a7',
#     'normalized_name': '25 June, 1974',
#     'start': 335,
#     'end': 348,
#     'text': '25 June, 1974',
#     'labels': ['DATE']},
#    {'id': 'a43e3892e67e4a96a178d6db8410c2c3',
#     'normalized_name': 'Karnataka High Court',
#     'start': 356,
#     'end': 376,
#     'text': 'Karnataka High Court',
#     'labels': ['COURT']}]},
#  {'start': 378,
#   'end': 540,
#   'text': '\nThe principal question in this appeal whether section 107 of the Karnataka Land Reforms Act, 1961 applies to the land in suit which was leased to the respondent.',
#   'labels': ['FAC'],
#   'id': 'b0de78d9ddab4070986bf8293c8ab43e_5',
#   'in_summary': False,
#   'sent_score': 0.2415706366300583,
#   'summary_section': 'facts',
#   'entities': [{'id': '626ebb91efb84eb782debfe64179012f',
#     'normalized_name': 'section 107 &&& Karnataka Land Reforms Act, 1961',
#     'start': 425,
#     'end': 436,
#     'text': 'section 107',
#     'labels': ['PROVISION']},
#    {'id': '92fb1af26144452a8a84bc9fb704f9a6',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 444,
#     'end': 476,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 541,
#   'end': 718,
#   'text': '\nA large plot of land comprising an area of about 20 acres popularly known as "The Chamaraja Sewage Farm" situate in the city of Bangalore belongs to the appellant Corpora tion.',
#   'labels': ['FAC'],
#   'id': '6ce534a124bc47d080c55a292f20c6cf_6',
#   'in_summary': False,
#   'sent_score': 0.18581295013427734,
#   'summary_section': 'facts',
#   'entities': [{'id': 'efd8b17f1a3b4304a50a517653cbbe30',
#     'normalized_name': 'Chamaraja Sewage Farm',
#     'start': 624,
#     'end': 645,
#     'text': 'Chamaraja Sewage Farm',
#     'labels': ['ORG']},
#    {'id': '20ea4c22310849809dd1493a3c5c3e0a',
#     'normalized_name': 'Bangalore',
#     'start': 670,
#     'end': 679,
#     'text': 'Bangalore',
#     'labels': ['GPE']}]},
#  {'start': 719,
#   'end': 894,
#   'text': '\nThe appellant :leased to the respondent by a regis tered lease dated 14 September, 270 1953 the aforementioned land for a period of 5 years on an annual rent of Rs. 13,555/ .',
#   'labels': ['FAC'],
#   'id': '85f95f9f0f2d4d32a1bb7c461b73502b_7',
#   'in_summary': False,
#   'sent_score': 0.39214664697647095,
#   'summary_section': 'facts',
#   'entities': [{'id': 'e13175db7cfc4dd39fd7892372aab276',
#     'normalized_name': '14 September, 270 1953',
#     'start': 789,
#     'end': 811,
#     'text': '14 September, 270 1953',
#     'labels': ['DATE']}]},
#  {'start': 895,
#   'end': 1025,
#   'text': '\nThe respondent by notice was called upon to hand over possession of the land immediately after the expiry of the period of lease.',
#   'labels': ['FAC'],
#   'id': '6cce5782dc224627ab6c6d9e301359e9_8',
#   'in_summary': False,
#   'sent_score': 0.49577298760414124,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1026,
#   'end': 1071,
#   'text': '\nThe respondent failed to deliver possession.',
#   'labels': ['FAC'],
#   'id': 'b88e73d87b7b44aabfa6f3c504bb2f5c_9',
#   'in_summary': False,
#   'sent_score': 0.4840843677520752,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1072,
#   'end': 1231,
#   'text': '\nThe reason why the appellant required that land is that the Corporation proposed a scheme for the development and construction of a new township on that area.',
#   'labels': ['FAC'],
#   'id': '9ca8531f853b4510b2c8c90e2a61b6c0_10',
#   'in_summary': False,
#   'sent_score': 0.35921362042427063,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1232,
#   'end': 1364,
#   'text': '\nThe respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession.',
#   'labels': ['FAC'],
#   'id': '08fd75f291384f4fb1b76f3035406b3e_11',
#   'in_summary': True,
#   'sent_score': 0.5512186884880066,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1365,
#   'end': 1464,
#   'text': '\nThe Court upheld the contentions of the appellant that the lease had terminated by efflux of time.',
#   'labels': ['FAC'],
#   'id': 'cca67127630c4418b10c9af7d9e69743_12',
#   'in_summary': False,
#   'sent_score': 0.4480699896812439,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1465,
#   'end': 1504,
#   'text': "\nThe respondent 's 'suit was dismissed.",
#   'labels': ['FAC'],
#   'id': '89fef5f6e1634949a5dc2f31e4e01e46_13',
#   'in_summary': False,
#   'sent_score': 0.40270137786865234,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1505,
#   'end': 1531,
#   'text': '\nAn appeal was pre ferred.',
#   'labels': ['FAC'],
#   'id': 'ba75f44c6aa34e2a9216281347436c4d_14',
#   'in_summary': False,
#   'sent_score': 0.33441075682640076,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1532,
#   'end': 1572,
#   'text': '\nThe appeal was dismissed on 21 August,.',
#   'labels': ['FAC'],
#   'id': 'f1589f9487584f8fb58872ba3120dbe6_15',
#   'in_summary': False,
#   'sent_score': 0.3846021294593811,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1573,
#   'end': 1664,
#   'text': '\nThe appellant then instituted the suit in appeal claim ing possession from the respondent.',
#   'labels': ['FAC'],
#   'id': 'c7c68a4205f046b692d3867fcbc02b52_16',
#   'in_summary': False,
#   'sent_score': 0.44347840547561646,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1665,
#   'end': 1775,
#   'text': '\nThe appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation.',
#   'labels': ['FAC'],
#   'id': 'dcfcd59898cc470994789c1e32004bf9_17',
#   'in_summary': True,
#   'sent_score': 0.5153099894523621,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1776,
#   'end': 1829,
#   'text': '\nThe respondent contended that he was still a tenant.',
#   'labels': ['FAC'],
#   'id': '20539d41e3164fff9546e4492981c374_18',
#   'in_summary': False,
#   'sent_score': 0.4836663603782654,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 1830,
#   'end': 1962,
#   'text': '\nThe respondent claimed protection under the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 being Act No. 15 of 1961.',
#   'labels': ['FAC'],
#   'id': 'ed9d5834432a40f0b04169746474aa03_19',
#   'in_summary': True,
#   'sent_score': 0.543417751789093,
#   'summary_section': 'facts',
#   'entities': [{'id': '7304098e137c4615ad2f20ca006e63c6',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 1875,
#     'end': 1936,
#     'text': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': 'c39eb8c2549c4919b755645b95bc2868',
#     'normalized_name': 'Act No. 15 of 1961',
#     'start': 1943,
#     'end': 1961,
#     'text': 'Act No. 15 of 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 1963,
#   'end': 2088,
#   'text': '\nSection 3 of the Mysore Tenants (Temporary Protection from Evic .\ntion) Act, 1961 provided for prohibition against eviction.',
#   'labels': ['FAC'],
#   'id': '18ae0044cc2e49dab64fdf188002ef71_20',
#   'in_summary': True,
#   'sent_score': 0.5198946595191956,
#   'summary_section': 'facts',
#   'entities': [{'id': '75f6ad1cb0c24fa0af4aadd23372a058',
#     'normalized_name': 'Section 3 &&& Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 1964,
#     'end': 1973,
#     'text': 'Section 3',
#     'labels': ['PROVISION']},
#    {'id': '0647a113cbd1440a9cd742db6b5efa9c',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 1981,
#     'end': 2045,
#     'text': 'Mysore Tenants (Temporary Protection from Evic .\ntion) Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 2089,
#   'end': 2134,
#   'text': '\nThe appellant obtained a decree in the suit.',
#   'labels': ['FAC'],
#   'id': '0611b20e978146fb9f69754c063265db_21',
#   'in_summary': True,
#   'sent_score': 0.5162997245788574,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 2135,
#   'end': 2193,
#   'text': '\nThe decree directed the respondent to deliver possession.',
#   'labels': ['FAC'],
#   'id': '5783ae9b419b42758a0a66da32bbde69_22',
#   'in_summary': False,
#   'sent_score': 0.5043925642967224,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 2194,
#   'end': 2233,
#   'text': "\nThe respond ent preferred an ' appeal.",
#   'labels': ['FAC'],
#   'id': '1a7e42b4a93546f8a66143f0e0644b5f_23',
#   'in_summary': False,
#   'sent_score': 0.42720478773117065,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 2234,
#   'end': 2315,
#   'text': '\nThe High Court remanded the matter to the trial Court for assessment of damages.',
#   'labels': ['FAC'],
#   'id': 'e70ec66c8fe44443b5d0caea07784ec1_24',
#   'in_summary': True,
#   'sent_score': 0.5515962243080139,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 2316,
#   'end': 2395,
#   'text': '\nUpon remand the respondent applied for the amendment of the written statement.',
#   'labels': ['FAC'],
#   'id': 'c2ad225b0d46469c9cbca30ae070ff26_25',
#   'in_summary': False,
#   'sent_score': 0.4199874699115753,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 2396,
#   'end': 2474,
#   'text': '\nThe respondent claimed protection under the Karnataka Land Reforms Act, 1961.',
#   'labels': ['FAC'],
#   'id': '45395a360b784a6e8032805555a729f1_26',
#   'in_summary': True,
#   'sent_score': 0.5767740607261658,
#   'summary_section': 'facts',
#   'entities': [{'id': '6663b2aea4fc42ac9adb952c6d12f1eb',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 2441,
#     'end': 2473,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 2475,
#   'end': 2606,
#   'text': '\nIt may be stated here that the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 ceased to be in force in March, 1966.',
#   'labels': ['FAC'],
#   'id': '6931923f2eaa4758b0456b7a74d2e184_27',
#   'in_summary': False,
#   'sent_score': 0.198588564991951,
#   'summary_section': 'facts',
#   'entities': [{'id': '3bc552a298c542b6aeefc92c4383343e',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 2507,
#     'end': 2568,
#     'text': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 2607,
#   'end': 2722,
#   'text': '\nThat is perhaps why the respondent made an applica tion for amendment of the written statement on 2 February 1973.',
#   'labels': ['FAC'],
#   'id': '92ed95c6e09f4ca3aae47098bc4b3ad1_28',
#   'in_summary': False,
#   'sent_score': 0.07754458487033844,
#   'summary_section': 'facts',
#   'entities': [{'id': 'e41e89da83b44b758b1f9f0aad5ba845',
#     'normalized_name': '2 February 1973',
#     'start': 2706,
#     'end': 2721,
#     'text': '2 February 1973',
#     'labels': ['DATE']}]},
#  {'start': 2723,
#   'end': 3569,
#   'text': "\nThe respondent contended relying on section 133 of the Karnataka Land Reforms Act, 1961 that the.\nsuit should be stayed by the civil court and should be referred to the Tribunal for decision.\nSection 112(B)(b) of the Karnataka Land Reforms Act, 1961 confers power on the Tribunal to decide inter alia whether a person is a tenant or not.\nThe respondent contended that he was a person who was deemed to be a tenant.\nThe appellant opposed the application for stay of the suit by the civil court and referring to the Tribunal for decision under the Karnataka Land Reforms Act, 1961.\nThe trial Court held that the land ' belonging to the appellant was exempted from the application of the provisions of the Land Reforms Act.\nThe trial Court dismissed the application of the respondent.\nThe respondent presented a revision petition t0 the High Court.",
#   'labels': ['FAC'],
#   'id': 'c87792a0d422488388e4a6ec5b86a5b4_29',
#   'in_summary': False,
#   'sent_score': 0.4705484211444855,
#   'summary_section': 'facts',
#   'entities': [{'id': 'b0455cbf22fe45058a7b3f79f9eab71a',
#     'normalized_name': 'section 133 &&& Karnataka Land Reforms Act, 1961',
#     'start': 2760,
#     'end': 2771,
#     'text': 'section 133',
#     'labels': ['PROVISION']},
#    {'id': '18f426785028400288c0630a432156cf',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 2779,
#     'end': 2811,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': '35ad1b9adf8e4086848e182c237cb3a8',
#     'normalized_name': 'Section 112(B)(b) &&& Karnataka Land Reforms Act, 1961',
#     'start': 2916,
#     'end': 2933,
#     'text': 'Section 112(B)(b)',
#     'labels': ['PROVISION']},
#    {'id': '9aff64ec1d0d4bd6974c2a0a228d25af',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 2941,
#     'end': 2973,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': 'a656bdf58e9148ca981c17497098d03d',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 3270,
#     'end': 3302,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': 'c769ec14414a45279388dd7b9fee3f73',
#     'normalized_name': 'Land Reforms Act',
#     'start': 3427,
#     'end': 3443,
#     'text': 'Land Reforms Act',
#     'labels': ['STATUTE']}]},
#  {'start': 3570,
#   'end': 3709,
#   'text': '\nThe High Court reversed the decision of the trial Court and directed the trial Court to refer such of the issues which are required to be.',
#   'labels': ['RLC'],
#   'id': 'c6ae8429375f4a94815a7fbe679d38ab_30',
#   'in_summary': False,
#   'sent_score': 0.3532833456993103,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 3710,
#   'end': 3735,
#   'text': '\ndecided by the Tribunal.',
#   'labels': ['FAC'],
#   'id': 'bc9fe44e733346b88051532077b3003c_31',
#   'in_summary': False,
#   'sent_score': 0.28702104091644287,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 3736,
#   'end': 3915,
#   'text': '\n271 Counsel for the respondent contended that the respondent is a tenant within the meaning of the word "tenant" defined in section 2(34) of the Karnataka Land Reforms Act, 1961.',
#   'labels': ['FAC'],
#   'id': 'c4a2d6d517fd4a648fdf0635542447f6_32',
#   'in_summary': False,
#   'sent_score': 0.25543850660324097,
#   'summary_section': 'facts',
#   'entities': [{'id': '1fc1d2a1357e4a52a49e6d3f3c246a72',
#     'normalized_name': 'section 2(34) &&& Karnataka Land Reforms Act, 1961',
#     'start': 3861,
#     'end': 3874,
#     'text': 'section 2(34)',
#     'labels': ['PROVISION']},
#    {'id': '96e2fa0804254d2e90c38839c26ee8c4',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 3882,
#     'end': 3914,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 3916,
#   'end': 4498,
#   'text': '\n"Tenant" is defined to mean an agriculturist who cultivates personally the land he holds on lease from a landlord and includes (i) a person who is deemed to be a tenant under section 4 of the Karnataka Land Reforms Act, 1961, Section of the Karnataka Land Reforms Act, 1961 states that a person lawfully cultivating any land belonging to another person shall be deemed to be a tenant if such land is not cultivat ed personally by the owner and if such person is not (a) a member of the owner \'s family, or (b) a servant or a hired labourer on wages, or (c) a mortgage in possession',
#   'labels': ['STA'],
#   'id': 'e900c756eedc4815a2fa3a2b932032fb_33',
#   'in_summary': False,
#   'sent_score': 0.15787264704704285,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': 'a440e94fda9448b48648716324563ad5',
#     'normalized_name': 'section 4 &&& Karnataka Land Reforms Act, 1961',
#     'start': 4092,
#     'end': 4101,
#     'text': 'section 4',
#     'labels': ['PROVISION']},
#    {'id': 'b0b4b88ca47146e391a86becbddfed9b',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 4109,
#     'end': 4141,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': '79eccae1e8b4437388da7d0eff87aea1',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 4158,
#     'end': 4190,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 4499,
#   'end': 4614,
#   'text': 'It was, therefore, said that the respondent could raise the con tention whether the respondent was a tenant or not.',
#   'labels': ['FAC'],
#   'id': '3043379bc4f843f69af20d74e2955a41_34',
#   'in_summary': False,
#   'sent_score': 0.1529998928308487,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 4615,
#   'end': 4844,
#   'text': '\nIt was next contended that section 8 of the Karnataka Land Reforms Act, 1961 speaks of rent and rent is referable to tenant and therefore a dispute as to tenancy would be within the ambit of the Karnataka Land Reforms Act, 1961.',
#   'labels': ['ANALYSIS'],
#   'id': '71134d00571e41c2aefc96a2bc3975df_35',
#   'in_summary': False,
#   'sent_score': 0.2897302806377411,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': 'c7fd972c309749f5a02c7404ad2f8a99',
#     'normalized_name': 'section 8 &&& Karnataka Land Reforms Act, 1961',
#     'start': 4643,
#     'end': 4652,
#     'text': 'section 8',
#     'labels': ['PROVISION']},
#    {'id': 'fc628fcc5c9343e4bde4a409595ccab0',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 4660,
#     'end': 4692,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': 'f23afe92baaf4832bdd0ba96fb465e80',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 4811,
#     'end': 4843,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 4845,
#   'end': 5233,
#   'text': "\nSection 107 of the Karnataka Land Reforms Act, 1961 states that subject to the provisions of section 110 nothing in this Act, except section 8 shall apply to lands, inter alia (iii) belonging to or held on lease or from a local authority.\nThere is no dispute that the land was given on lease by the local authority.\nThere is also no 'dispute that the land belongs to the local authority.",
#   'labels': ['STA'],
#   'id': 'a4798fde22344cc4a623f1fdb1a5fcaf_36',
#   'in_summary': False,
#   'sent_score': 0.42977386713027954,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '3dcc8494e68b44c99fa6b78ca8d57049',
#     'normalized_name': 'Section 107 &&& Karnataka Land Reforms Act, 1961',
#     'start': 4846,
#     'end': 4857,
#     'text': 'Section 107',
#     'labels': ['PROVISION']},
#    {'id': '10ab190350164d3184ee576bdee6bac7',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 4865,
#     'end': 4897,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': '06fb18a05c6140699c1e27f84e370993',
#     'normalized_name': 'section 110 &&& Karnataka Land Reforms Act, 1961',
#     'start': 4939,
#     'end': 4950,
#     'text': 'section 110',
#     'labels': ['PROVISION']},
#    {'id': 'b9309b3c23514387ad0eb4f185a47bfa',
#     'normalized_name': 'section 8 &&& Karnataka Land Reforms Act, 1961',
#     'start': 4979,
#     'end': 4988,
#     'text': 'section 8',
#     'labels': ['PROVISION']}]},
#  {'start': 5234,
#   'end': 5307,
#   'text': '\nThere is also no dispute that the lease was detrmined by efflux of time.',
#   'labels': ['ANALYSIS'],
#   'id': '5150fc3822fc4707b2699747af0fa1e4_37',
#   'in_summary': False,
#   'sent_score': 0.39163100719451904,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 5308,
#   'end': 5687,
#   'text': "\nThe question whether the respondent is a tenant or deemed to be a tenant does not at all arise because the tenancy came to an end.\nThe 'respondent thereafter was a trespasser.\nSection 107 of the Karnataka Land Reforms Act, 1961 makes it quite clear that the only provision which applies, inter alia, to lands belonging to or hold on lease or from a local authority is section 8.",
#   'labels': ['ANALYSIS'],
#   'id': '732871a52e4540ec8607c896a6c2e191_38',
#   'in_summary': False,
#   'sent_score': 0.43952181935310364,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': 'a0442e6ac1d8464c9220cc1e262193d1',
#     'normalized_name': 'Section 107 &&& Karnataka Land Reforms Act, 1961',
#     'start': 5485,
#     'end': 5496,
#     'text': 'Section 107',
#     'labels': ['PROVISION']},
#    {'id': 'd7c1e96c35e24423bb633f61802da699',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 5504,
#     'end': 5536,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': 'f0533677f55546f9aaab1ec48cd500f5',
#     'normalized_name': 'section 8 &&& Karnataka Land Reforms Act, 1961',
#     'start': 5677,
#     'end': 5686,
#     'text': 'section 8',
#     'labels': ['PROVISION']}]},
#  {'start': 5688,
#   'end': 5753,
#   'text': '\nNo other section of the Land Reforms Act applies to these lands.',
#   'labels': ['ANALYSIS'],
#   'id': '3410366c1e404c56944266b005385fc9_39',
#   'in_summary': False,
#   'sent_score': 0.38902732729911804,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '0f69b6b0f11746bc965ec6d864a7f030',
#     'normalized_name': 'Land Reforms Act',
#     'start': 5713,
#     'end': 5729,
#     'text': 'Land Reforms Act',
#     'labels': ['STATUTE']}]},
#  {'start': 5754,
#   'end': 5822,
#   'text': '\nSection 8 of the Karna taka Land Reforms Act, 1961 deals with rent.',
#   'labels': ['ANALYSIS'],
#   'id': 'f0331520d22448a1b35dd7d5d35477e6_40',
#   'in_summary': False,
#   'sent_score': 0.4349290132522583,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '2a0928b4711d4cc78f791fee35df0d55',
#     'normalized_name': 'Section 8 &&& Karnataka Land Reforms Act, 1961',
#     'start': 5755,
#     'end': 5764,
#     'text': 'Section 8',
#     'labels': ['PROVISION']},
#    {'id': '7680a8c923584074a852a8342ce35d86',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 5772,
#     'end': 5805,
#     'text': 'Karna taka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 5823,
#   'end': 5882,
#   'text': '\nThe suit in the present case was not for recovery of rent.',
#   'labels': ['ANALYSIS'],
#   'id': 'df347fee4b06412dae3ba5c3488771eb_41',
#   'in_summary': False,
#   'sent_score': 0.44368693232536316,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 5883,
#   'end': 5986,
#   'text': '\nThe suit is for recovery of possession and for damages, for unauthorised occupation of the respondent.',
#   'labels': ['ANALYSIS'],
#   'id': 'd38d2313b48442a0ad2936b83ae980c7_42',
#   'in_summary': True,
#   'sent_score': 0.6126056909561157,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 5987,
#   'end': 6056,
#   'text': '\nSection 2 of the Karnataka Land Reforms Act, 1961 is not applicable.',
#   'labels': ['ANALYSIS'],
#   'id': '27408c051c2647a79ebae6b4f392710c_43',
#   'in_summary': True,
#   'sent_score': 0.5244702100753784,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '0d3fd263dae24dc2af0b4609b1659ab9',
#     'normalized_name': 'Section 2 &&& Karnataka Land Reforms Act, 1961',
#     'start': 5988,
#     'end': 5997,
#     'text': 'Section 2',
#     'labels': ['PROVISION']},
#    {'id': 'c05b7c49629c4a45848549a296ad219b',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 6005,
#     'end': 6037,
#     'text': 'Karnataka Land Reforms Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 6057,
#   'end': 6149,
#   'text': '\nTherefore, no question can be referred for determination by the Tribunal under section 133.',
#   'labels': ['ANALYSIS'],
#   'id': 'f2de0163ebc746119ae1043d761a3ba7_44',
#   'in_summary': False,
#   'sent_score': 0.5102759003639221,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '549670be08f049788749a4b017e5614c',
#     'normalized_name': 'section 133 &&& Karnataka Land Reforms Act, 1961',
#     'start': 6137,
#     'end': 6148,
#     'text': 'section 133',
#     'labels': ['PROVISION']}]},
#  {'start': 6150,
#   'end': 6255,
#   'text': '\nThe Mysore Tenants (Temporary Protection from Eviction) Act, 1961 came into effect on 13 December, 1961.',
#   'labels': ['ANALYSIS'],
#   'id': 'ea34d08f92424270933ceafd94a2fa34_45',
#   'in_summary': True,
#   'sent_score': 0.5982503294944763,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '9ccb301b07f14bf5a52cf9b07a75814c',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 6155,
#     'end': 6216,
#     'text': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'labels': ['STATUTE']},
#    {'id': '1f3b37a92e7d4f2d8bafcfe62a7201d8',
#     'normalized_name': '13 December, 1961',
#     'start': 6237,
#     'end': 6254,
#     'text': '13 December, 1961',
#     'labels': ['DATE']}]},
#  {'start': 6256,
#   'end': 6371,
#   'text': '\nThe Mysore Tenants (Temporary Protection from Eviction) Act, 1961 remained in force till the month of March, 1966.',
#   'labels': ['FAC'],
#   'id': '416193d9bcea4054b53093af7d08a334_46',
#   'in_summary': True,
#   'sent_score': 0.5689080953598022,
#   'summary_section': 'facts',
#   'entities': [{'id': '94e886e12c2e401d82b2add1a21c3127',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 6261,
#     'end': 6322,
#     'text': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 6372,
#   'end': 6463,
#   'text': '\nThe re spondent could not draw any support from that Act for pro tection against eviction.',
#   'labels': ['ANALYSIS'],
#   'id': '46a9d550a7264634ba2e13069c288904_47',
#   'in_summary': False,
#   'sent_score': 0.4716862142086029,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 6464,
#   'end': 6586,
#   'text': '\nThe land in question was outside the applicability of the Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961.',
#   'labels': ['FAC'],
#   'id': '5c3f14a7b6db4a05ac46a3510816dc76_48',
#   'in_summary': True,
#   'sent_score': 0.5759619474411011,
#   'summary_section': 'facts',
#   'entities': [{'id': '0da6187182754acfb2cfaddb669d8462',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 6523,
#     'end': 6585,
#     'text': 'Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 6587,
#   'end': 6812,
#   'text': '\nFurther the Act ceased to be in operation in 1966 and no question could be referred for determination as to whether the respondent was a tenant under the Mysore Tenants (Temporary Protection from Evic tion) Act, 1961 or not.',
#   'labels': ['ANALYSIS'],
#   'id': '80a07fc6ed704d338c0d7a4a94d7f6e3_49',
#   'in_summary': True,
#   'sent_score': 0.5590600967407227,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '31567cfb3f904c13bfa4bb6e4cc883bd',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 6742,
#     'end': 6804,
#     'text': 'Mysore Tenants (Temporary Protection from Evic tion) Act, 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 6813,
#   'end': 6930,
#   'text': '\nThe trial Court in the present case rightly said that it could not be said that there was any dispute as to tenancy.',
#   'labels': ['ANALYSIS'],
#   'id': '349bde5006c94163ab3c021bf10a067f_50',
#   'in_summary': False,
#   'sent_score': 0.5036259293556213,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 6931,
#   'end': 7009,
#   'text': '\n272 The respondent had filed a suit where he claimed to remain in possession.',
#   'labels': ['FAC'],
#   'id': 'c9c74def44684fd58704de0357ca940e_51',
#   'in_summary': False,
#   'sent_score': 0.38909363746643066,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 7010,
#   'end': 7052,
#   'text': '\nThe suit of the respondent was dismissed.',
#   'labels': ['FAC'],
#   'id': '270dfd877d36466b8b6dd0a32588a261_52',
#   'in_summary': False,
#   'sent_score': 0.4935670793056488,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 7053,
#   'end': 7177,
#   'text': '\nThe appellant all along contended that the lease dated 14 September 1963 for a period of 5 years expired by efflux of time.',
#   'labels': ['FAC'],
#   'id': 'f49cc952dc824100a5957b84ac224466_53',
#   'in_summary': False,
#   'sent_score': 0.46178439259529114,
#   'summary_section': 'facts',
#   'entities': [{'id': 'b965dabb7d784704a5c54917ef4b5375',
#     'normalized_name': '14 September 1963',
#     'start': 7109,
#     'end': 7126,
#     'text': '14 September 1963',
#     'labels': ['DATE']}]},
#  {'start': 7178,
#   'end': 7318,
#   'text': '\nThe appellant claimed possession on the ground Of unauthorised occupation and claimed damages against the respondent, who was a trespasser.',
#   'labels': ['FAC'],
#   'id': 'fd7a89bc8b7748dba331612778be4127_54',
#   'in_summary': False,
#   'sent_score': 0.5066825151443481,
#   'summary_section': 'facts',
#   'entities': []},
#  {'start': 7319,
#   'end': 7569,
#   'text': '\nThe High Court was clearly in error in referring to the Tribunal under the Karnataka Land Reforms Act 1961 determi nation of the plea taken by the respondent that he was pro tected by the Mysore Tenants (Temporary Protection from Eviction) Act 1961.',
#   'labels': ['ANALYSIS'],
#   'id': '43d5f2d690de436ba147d7107eab9d45_55',
#   'in_summary': True,
#   'sent_score': 0.5564194321632385,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': 'f0336d146d5b481f91c95a7903aeb630',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 7395,
#     'end': 7426,
#     'text': 'Karnataka Land Reforms Act 1961',
#     'labels': ['STATUTE']},
#    {'id': '1b7d1424a07644ad934b6b3079117b36',
#     'normalized_name': 'Mysore Tenants (Temporary Protection from Eviction) Act, 1961',
#     'start': 7508,
#     'end': 7568,
#     'text': 'Mysore Tenants (Temporary Protection from Eviction) Act 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 7570,
#   'end': 7642,
#   'text': '\nCounsel for the respondent did not support the judgment on that ground.',
#   'labels': ['ARG_PETITIONER'],
#   'id': '75a0a10c83ff42948512523f11b9f08f_56',
#   'in_summary': True,
#   'sent_score': 0.0764058530330658,
#   'summary_section': 'arguments',
#   'entities': []},
#  {'start': 7643,
#   'end': 7840,
#   'text': '\nCounsel for the respondent contended that section 133 of the Karnataka Land Reforms Act 1961 excludes jurisdiction of Civil court in suits for possession where the defendant claims to be a tenant.',
#   'labels': ['ARG_PETITIONER'],
#   'id': 'b4af5ff612f9483d844686baba295b52_57',
#   'in_summary': True,
#   'sent_score': 0.40778931975364685,
#   'summary_section': 'arguments',
#   'entities': [{'id': 'e0d376e02ab644d89e4569e4a9d08315',
#     'normalized_name': 'section 133 &&& Karnataka Land Reforms Act, 1961',
#     'start': 7686,
#     'end': 7697,
#     'text': 'section 133',
#     'labels': ['PROVISION']},
#    {'id': '7dcf9fec1d554715b33e01cb2f38aa8b',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 7705,
#     'end': 7736,
#     'text': 'Karnataka Land Reforms Act 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 7841,
#   'end': 7888,
#   'text': '\nThe plea of the respondent is utterly unsound.',
#   'labels': ['RATIO'],
#   'id': '63fdf3cb73ae4480b4bba5cf38cafb11_58',
#   'in_summary': False,
#   'sent_score': 0.3284624218940735,
#   'summary_section': 'ANALYSIS',
#   'entities': []},
#  {'start': 7889,
#   'end': 8152,
#   'text': '\nSection 133 of the Karnataka Land Reforms Act 1961 cannot apply to lands which are held by a person on lease from the local authority or where the lease had ex pired and the local authority sues for possession on the ground that there is unauthorised occupation.',
#   'labels': ['RATIO'],
#   'id': '1022da8debee49768955bbe2eac00a1c_59',
#   'in_summary': True,
#   'sent_score': 0.6430705189704895,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': '5a0191d36aa24e04a8a83d978541a4f7',
#     'normalized_name': 'Section 133 &&& Karnataka Land Reforms Act, 1961',
#     'start': 7890,
#     'end': 7901,
#     'text': 'Section 133',
#     'labels': ['PROVISION']},
#    {'id': 'a6c1e55096b2495294352eebd0b0ceb9',
#     'normalized_name': 'Karnataka Land Reforms Act, 1961',
#     'start': 7909,
#     'end': 7940,
#     'text': 'Karnataka Land Reforms Act 1961',
#     'labels': ['STATUTE']}]},
#  {'start': 8153,
#   'end': 8317,
#   'text': '\nNo provision of the Karnataka Land Reforms Act can be relied upon to contend that there should be protection against recovery of possession by the local authority.',
#   'labels': ['RATIO'],
#   'id': 'bb9d860082824758a3050e538495bba1_60',
#   'in_summary': True,
#   'sent_score': 0.6569492816925049,
#   'summary_section': 'ANALYSIS',
#   'entities': [{'id': 'd59f79df3f4b47d9b3d82fdc72c6601f',
#     'normalized_name': 'Karnataka Land Reforms Act',
#     'start': 8174,
#     'end': 8200,
#     'text': 'Karnataka Land Reforms Act',
#     'labels': ['STATUTE']}]},
#  {'start': 8318,
#   'end': 8389,
#   'text': '\nFor the foregoing reasons the judgment of the High Court is set aside.',
#   'labels': ['RPC'],
#   'id': 'bcd8441bd05d4b248889039c115bebc5_61',
#   'in_summary': True,
#   'sent_score': 0.026695234701037407,
#   'summary_section': 'decision'},
#  {'start': 8390,
#   'end': 8493,
#   'text': '\nIn view of the fact that no costs were al lowed by the High Court, there will be no order as to costs.',
#   'labels': ['RPC'],
#   'id': 'bc4f8b78ff6f4bdab0cb28fc36e71ae5_62',
#   'in_summary': True,
#   'sent_score': 0.02291005849838257,
#   'summary_section': 'decision'},
#  {'start': 8494,
#   'end': 8515,
#   'text': '\nM.R. Appeal allowed.',
#   'labels': ['NONE'],
#   'id': 'f5560eb204c14fc6bd9b883c17f541fd_63',
#   'in_summary': False}]

# %%
results[0]['summary']
# Out:
# {'PREAMBLE': 'Appeal No. 623 of 1975.\n',
#  'facts': '\nThe respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession.\n\nThe appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation.\n\nThe respondent claimed protection under the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 being Act No. 15 of 1961.\n\nSection 3 of the Mysore Tenants (Temporary Protection from Evic .\ntion) Act, 1961 provided for prohibition against eviction.\n\nThe appellant obtained a decree in the suit.\n\nThe High Court remanded the matter to the trial Court for assessment of damages.\n\nThe respondent claimed protection under the Karnataka Land Reforms Act, 1961.\n\nThe Mysore Tenants (Temporary Protection from Eviction) Act, 1961 remained in force till the month of March, 1966.\n\nThe land in question was outside the applicability of the Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961.\n',
#  'ANALYSIS': '\nThe suit is for recovery of possession and for damages, for unauthorised occupation of the respondent.\n\nSection 2 of the Karnataka Land Reforms Act, 1961 is not applicable.\n\nThe Mysore Tenants (Temporary Protection from Eviction) Act, 1961 came into effect on 13 December, 1961.\n\nFurther the Act ceased to be in operation in 1966 and no question could be referred for determination as to whether the respondent was a tenant under the Mysore Tenants (Temporary Protection from Evic tion) Act, 1961 or not.\n\nThe High Court was clearly in error in referring to the Tribunal under the Karnataka Land Reforms Act 1961 determi nation of the plea taken by the respondent that he was pro tected by the Mysore Tenants (Temporary Protection from Eviction) Act 1961.\n\nSection 133 of the Karnataka Land Reforms Act 1961 cannot apply to lands which are held by a person on lease from the local authority or where the lease had ex pired and the local authority sues for possession on the ground that there is unauthorised occupation.\n\nNo provision of the Karnataka Land Reforms Act can be relied upon to contend that there should be protection against recovery of possession by the local authority.\n',
#  'arguments': '\nCounsel for the respondent did not support the judgment on that ground.\n\nCounsel for the respondent contended that section 133 of the Karnataka Land Reforms Act 1961 excludes jurisdiction of Civil court in suits for possession where the defendant claims to be a tenant.\n',
#  'decision': '\nFor the foregoing reasons the judgment of the High Court is set aside.\n\nIn view of the fact that no costs were al lowed by the High Court, there will be no order as to costs.\n'}

# %%
from spacy import displacy
from opennyai.ner.ner_utils import ner_displacy_option

# %%
displacy.render(pipeline._ner_model_output[0], style='ent', options=ner_displacy_option)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Appeal No. 623 of 1975
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
# . </br>From the Judgment and Order dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 6 74
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karna taka 'High Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
#  in
# <mark class="entity" style="background: #fbb1cf; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Civil Revision No 1981/73
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CASE_NUMBER</span>
# </mark>
# . </br>
# <mark class="entity" style="background: #b0f6a2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.S. JavaIi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">OTHER_PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #b0f6a2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     B.P. Singh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">OTHER_PERSON</span>
# </mark>
# , for the Appellants. </br>
# <mark class="entity" style="background: #b0f6a2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S.V. Gupte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">OTHER_PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #b0f6a2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     K.N. Bhatt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">OTHER_PERSON</span>
# </mark>
# , for the Respondent. </br>The Judgment of the Court was delivered by
# <mark class="entity" style="background: #fdd8a5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RAY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">JUDGE</span>
# </mark>
# , C.J.</br>This appeal by special leave is from the judgment .dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 June, 1974
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the
# <mark class="entity" style="background: #bbabf2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka High Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">COURT</span>
# </mark>
# . </br>The principal question in this appeal whether
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     section 107
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROVISION</span>
# </mark>
#  of the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Karnataka Land Reforms Act, 1961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUTE</span>
# </mark>
#  applies to the land in suit which was leased to the respondent. </br>A large plot of land comprising an area of about 20 acres popularly known as &quot;The
# <mark class="entity" style="background: #a57db5; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chamaraja Sewage Farm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# &quot; situate in the city of
# <mark class="entity" style="background: #7fdbd4; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bangalore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  belongs to the appellant Corpora tion. </br>The appellant :leased to the respondent by a regis tered lease dated
# <mark class="entity" style="background: #b1ecf7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14 September, 270 1953
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the aforementioned land for a period of 5 years on an annual rent of Rs. 13,555/ . </br>The respondent by notice was called upon to hand over possession of the land immediately after the expiry of the period of lease. </br>The respondent failed to deliver possession. </br>The reason why the appellant required that land is that the Corporation proposed a scheme for the development and construction of a new township on that area. </br>The respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession. </br>The Court upheld the contentions of the appellant that the lease had terminated by efflux of time. </br>The respondent 's 'suit was dismissed. </br>An appeal was pre ferred. </br>The appeal was dismissed on 21 August,. </br>The appellant then instituted the suit in appeal claim ing possession from the respondent. </br>The appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation. </br>The respondent contended that he was still a tenant. </br>The respondent claimed protection under the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mysore Tenants (Temporary Protection from Eviction) Act, 1961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUTE</span>
# </mark>
#  being
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Act No. 15 of 1961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUTE</span>
# </mark>
# . </br>
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Section 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROVISION</span>
# </mark>
#  of the
# <mark class="entity" style="background: #faea99; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mysore Tenants (Temporary Pr

# %%
print(len(pipeline.__ner_extractor__.nlp.tokenizer(text)))
# Out:
# 1699

# %%
import re

# %%
def clean_summary(summary_dict):
    cleaned = {}
    for section, text in summary_dict.items():
        # Remove stray " ."
        text = re.sub(r'\s+\.', '.', text)
        # Remove all newlines
        text = text.replace('\n', '')
        # Optional: Strip extra spaces
        text = re.sub(r'\s+', ' ', text).strip()
        cleaned[section] = text
    return cleaned

# %%
summary = results[0]['summary']
cleaned_summary = clean_summary(summary)

# %%
cleaned_summary
# Out:
# {'PREAMBLE': 'Appeal No. 623 of 1975.',
#  'facts': 'The respondent filed a suit for the grant of a permanent injunction restraining the appellant from interfering with the possession.The appellant contended that the respondent was a trespasser and claimed damages for unauthorised occupation.The respondent claimed protection under the Mysore Tenants (Temporary Protection from Eviction) Act, 1961 being Act No. 15 of 1961.Section 3 of the Mysore Tenants (Temporary Protection from Evic.tion) Act, 1961 provided for prohibition against eviction.The appellant obtained a decree in the suit.The High Court remanded the matter to the trial Court for assessment of damages.The respondent claimed protection under the Karnataka Land Reforms Act, 1961.The Mysore Tenants (Temporary Protection from Eviction) Act, 1961 remained in force till the month of March, 1966.The land in question was outside the applicability of the Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961.',
#  'ANALYSIS': 'The suit is for recovery of possession and for damages, for unauthorised occupation of the respondent.Section 2 of the Karnataka Land Reforms Act, 1961 is not applicable.The Mysore Tenants (Temporary Protection from Eviction) Act, 1961 came into effect on 13 December, 1961.Further the Act ceased to be in operation in 1966 and no question could be referred for determination as to whether the respondent was a tenant under the Mysore Tenants (Temporary Protection from Evic tion) Act, 1961 or not.The High Court was clearly in error in referring to the Tribunal under the Karnataka Land Reforms Act 1961 determi nation of the plea taken by the respondent that he was pro tected by the Mysore Tenants (Temporary Protection from Eviction) Act 1961.Section 133 of the Karnataka Land Reforms Act 1961 cannot apply to lands which are held by a person on lease from the local authority or where the lease had ex pired and the local authority sues for possession on the ground that there is unauthorised occupation.No provision of the Karnataka Land Reforms Act can be relied upon to contend that there should be protection against recovery of possession by the local authority.',
#  'arguments': 'Counsel for the respondent did not support the judgment on that ground.Counsel for the respondent contended that section 133 of the Karnataka Land Reforms Act 1961 excludes jurisdiction of Civil court in suits for possession where the defendant claims to be a tenant.',
#  'decision': 'For the foregoing reasons the judgment of the High Court is set aside.In view of the fact that no costs were al lowed by the High Court, there will be no order as to costs.'}

# %%
ner_doc_1 = pipeline._ner_model_output[0]
identified_entites = [(ent, ent.label_) for ent in ner_doc_1.ents]

# %%
identified_entites
# Out:
# [(Appeal No. 623 of 1975, 'CASE_NUMBER'),
#  (25 6 74, 'DATE'),
#  (Karna taka 'High Court, 'COURT'),
#  (Civil Revision No 1981/73, 'CASE_NUMBER'),
#  (S.S. JavaIi, 'OTHER_PERSON'),
#  (B.P. Singh, 'OTHER_PERSON'),
#  (S.V. Gupte, 'OTHER_PERSON'),
#  (K.N. Bhatt, 'OTHER_PERSON'),
#  (RAY, 'JUDGE'),
#  (25 June, 1974, 'DATE'),
#  (Karnataka High Court, 'COURT'),
#  (section 107, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Chamaraja Sewage Farm, 'ORG'),
#  (Bangalore, 'GPE'),
#  (14 September, 270 1953, 'DATE'),
#  (Mysore Tenants (Temporary Protection from Eviction) Act, 1961, 'STATUTE'),
#  (Act No. 15 of 1961, 'STATUTE'),
#  (Section 3, 'PROVISION'),
#  (Mysore Tenants (Temporary Protection from Evic .
#   tion) Act, 1961,
#   'STATUTE'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Mysore Tenants (Temporary Protection from Eviction) Act, 1961, 'STATUTE'),
#  (2 February 1973, 'DATE'),
#  (section 133, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Section 112(B)(b), 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Land Reforms Act, 'STATUTE'),
#  (section 2(34), 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (section 4, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (section 8, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (Section 107, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (section 110, 'PROVISION'),
#  (section 8, 'PROVISION'),
#  (Section 107, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (section 8, 'PROVISION'),
#  (Land Reforms Act, 'STATUTE'),
#  (Section 8, 'PROVISION'),
#  (Karna taka Land Reforms Act, 1961, 'STATUTE'),
#  (Section 2, 'PROVISION'),
#  (Karnataka Land Reforms Act, 1961, 'STATUTE'),
#  (section 133, 'PROVISION'),
#  (Mysore Tenants (Temporary Protection from Eviction) Act, 1961, 'STATUTE'),
#  (13 December, 1961, 'DATE'),
#  (Mysore Tenants (Temporary Protection from Eviction) Act, 1961, 'STATUTE'),
#  (Mysore Tenants (Temporary Protec tion from Eviction) Act, 1961, 'STATUTE'),
#  (Mysore Tenants (Temporary Protection from Evic tion) Act, 1961, 'STATUTE'),
#  (14 September 1963, 'DATE'),
#  (Karnataka Land Reforms Act 1961, 'STATUTE'),
#  (Mysore Tenants (Temporary Protection from Eviction) Act 1961, 'STATUTE'),
#  (section 133, 'PROVISION'),
#  (Karnataka Land Reforms Act 1961, 'STATUTE'),
#  (Section 133, 'PROVISION'),
#  (Karnataka Land Reforms Act 1961, 'STATUTE'),
#  (Karnataka Land Reforms Act, 'STATUTE')]
